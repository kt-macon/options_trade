# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# %%
# buy stock profit/loss

def buy_stock(x, stock_price):
        
    # Generate a range of stock prices (x) based on lognormal distribution
    x_range = np.linspace(0, stock_price * 3, 1000)  # Adjusted range for lognormal distribution
    
    # Calculate the lognormal distribution curve for the stock prices
    pdf = lognorm.pdf(x_range, sigma, scale=np.exp(mu))  # Lognormal distribution
    
    # Calculate the profit for the covered write strategy for each stock price in the range
    profits = x_range - stock_price
    
    # Break-even Point
    break_even_x = stock_price
    probability_x_above_break_even = 1 - lognorm.cdf(break_even_x, sigma, scale=np.exp(mu))
    
    # Max Profit Point
    probability_x_above_strike_price = 1 - lognorm.cdf(strike_price, sigma, scale=np.exp(mu))
    
    # Calculate the expected profit using numerical integration (simpson method)
    expected_profit = simpson(profits * pdf, x_range)
    cost = stock_price + call_price
    expected_profit_rate = expected_profit / cost
    
    data = {
        'Break-even Point': break_even_x,
        'Break-even Probability (%)': probability_x_above_break_even * 100,
        'Max Profit Point': strike_price,
        'Max Profit Probability (%)': probability_x_above_strike_price * 100,
        'Expected Profit': expected_profit,
        'Expected Profit Rate (%)': expected_profit_rate * 100,
    }
    
    # Print the results
    print(f"Break-even Point: {break_even_x:.4f}")
    print(f"Break-even Probability: {probability_x_above_break_even*100:.2f}%")
    print(f"Max Profit Point: {strike_price:.4f}")
    print(f"Max Profit Probability: {probability_x_above_strike_price*100:.2f}%")
    print(f"Expected Profit: {expected_profit:.4f}")
    print(f"Expected Profit Rate: {expected_profit_rate*100:.2f}%")
    
    return data

# %%
# buy call Option profit/loss

def buy_call(x, call_price, strike_price):
    # Profit = max(0, x - strike_price) - call_price
    return np.maximum(0, x - strike_price) - call_price

# %%
# Sell Call Option profit/loss
def sell_call(x, call_price, strike_price):
    # Profit = min(0, strike price - x) + call price
    return np.minimum(0, strike_price - x) + call_price

# %%
# Buy Put Option profit/loss
def buy_put(x, put_price, strike_price):
    # Profit = max(0, strike price - x) - put price
    return np.maximum(0, strike_price - x) - put_price

# %%
# Sell Put Option profit/loss
def sell_put(x, put_price, strike_price):
    # Profit = min(0, x - strike price) + put price
    return np.minimum(0, x - strike_price) + put_price

# %%
# Covered Write Strategy profit/loss
def covered_write(x, stock_price, call_price, strike_price):
    # Profit from stock: (Stock price - Buy price)
    stock_profit = buy_stock(x, stock_price)
    
    # Profit from selling the call: sell_call(x, call_price, strike_price)
    call_profit = sell_call(x, call_price, strike_price)
    
    # Total profit from covered write strategy
    return stock_profit + call_profit

# %%
# Assume stock price follow lognormal distribution
#which means the log of price follow normal distribution

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import lognorm
from scipy.integrate import simpson

def covered_write_profit_possibility_lognorm(stock_price, call_price, strike_price, sigma):
    # Parameters
    mu = np.log(stock_price)  # Mean of the log of the stock price (lognormal)
    num_simulations = 10000  # Number of simulations
    
    # Generate a range of stock prices (x) based on lognormal distribution
    x_range = np.linspace(0, stock_price * 3, 1000)  # Adjusted range for lognormal distribution
    
    # Calculate the lognormal distribution curve for the stock prices
    pdf = lognorm.pdf(x_range, sigma, scale=np.exp(mu))  # Lognormal distribution
    
    # Calculate the profit for the covered write strategy for each stock price in the range
    profits = covered_write(x_range, stock_price, call_price, strike_price)
    
    # Break-even Point
    break_even_x = stock_price - call_price
    probability_x_above_break_even = 1 - lognorm.cdf(break_even_x, sigma, scale=np.exp(mu))
    
    # Max Profit Point
    probability_x_above_strike_price = 1 - lognorm.cdf(strike_price, sigma, scale=np.exp(mu))
    
    # Calculate the expected profit using numerical integration (simpson method)
    expected_profit = simpson(profits * pdf, x_range)
    cost = stock_price + call_price
    expected_profit_rate = expected_profit / cost
    
     # Prepare the data to return
    data = {
        'Break-even Point': break_even_x,
        'Break-even Probability (%)': probability_x_above_break_even * 100,
        'Max Profit Point': strike_price,
        'Max Profit Probability (%)': probability_x_above_strike_price * 100,
        'Expected Profit': expected_profit,
        'Expected Profit Rate (%)': expected_profit_rate * 100,
    }
    
    # Print the results
    print(f"Break-even Point: {break_even_x:.4f}")
    print(f"Break-even Probability: {probability_x_above_break_even*100:.2f}%")
    print(f"Max Profit Point: {strike_price:.4f}")
    print(f"Max Profit Probability: {probability_x_above_strike_price*100:.2f}%")
    print(f"Expected Profit: {expected_profit:.4f}")
    print(f"Expected Profit Rate: {expected_profit_rate*100:.2f}%")

    
    # Plotting the lognormal distribution curve of stock prices
    fig, ax1 = plt.subplots(figsize=(10, 6))

    # Plot the lognormal distribution curve
    ax1.plot(x_range, pdf, color='blue', label='Lognormal Distribution of Stock Prices', linewidth=2)
    ax1.set_xlabel("Stock Price at Expiration")
    ax1.set_ylabel("Probability Density", color='blue')
    ax1.tick_params(axis='y', labelcolor='blue')

    # Add vertical dashed lines at 1 sigma and 2 sigma (lognormal is skewed, so these don't correspond directly)
    ax1.axvline(stock_price * np.exp(-sigma), color='grey', linestyle='--', linewidth=2)
    ax1.axvline(stock_price * np.exp(sigma), color='grey', linestyle='--', linewidth=2)

    # Profit/Loss Curve    
    
    # Create a second y-axis to plot the profit range
    ax2 = ax1.twinx()    
    # Add a horizontal line at y = 0 on the second y-axis
    ax2.axhline(0, color='black', linestyle='--', linewidth=1)
    # Plot the profit range for the covered write strategy
    ax2.plot(x_range, profits, color='green', label='Covered Write Strategy Profit', linewidth=2)
    ax2.set_ylabel("Profit/Loss", color='green')
    ax2.tick_params(axis='y', labelcolor='green')

    # Break-even Point Ploting
    
    # Plot break-even point and other important values
    ax2.scatter(break_even_x, 0, color='red', zorder=5)
    ax2.text(break_even_x + 0.05, -0.1, f"Break-even: {break_even_x:.4f}", fontsize=12, color="red")
    # Shade the area where x > break-even
    ax1.fill_between(x_range, pdf, where=(x_range >= break_even_x), 
                     color='lightgreen', alpha=0.5, label=f"Area where x > Break-even (P = {probability_x_above_break_even*100:.2f}%)")
    # Add vertical dashed lines at the break-even point
    ax1.axvline(break_even_x, color='red', linestyle='--', linewidth=2, label=f"Break-even Point: {break_even_x:.2f}")
    # Annotate the probability of x > break-even
    ax1.text(break_even_x + 0.2, max(pdf) * 0.5, 
             f"P(x > Break-even) = {probability_x_above_break_even*100:.2f}%", fontsize=12, color="red")

       
    # Current Stock Price Ploting
    
    # Add vertical dashed line for the current stock price (buy price)
    ax1.axvline(stock_price, color='orange', linestyle='--', linewidth=2, label=f"Current Stock Price: {stock_price}")
    # Annotate the current stock price on the x-axis
    ax1.text(stock_price, -0.02, f"{stock_price}", fontsize=12, color='orange', ha='center')

    # Max Profit Point Ploting
    
    # Shade the area where x > strike price (max profit region)
    ax1.fill_between(x_range, pdf, where=(x_range >= strike_price), 
                     color='lightcoral', alpha=0.5, label=f"Area where x > Strike Price (P = {probability_x_above_strike_price*100:.2f}%)")
    # Add vertical dashed lines at the strike price (max profit point)
    ax1.axvline(strike_price, color='purple', linestyle='--', linewidth=2, label=f"Max Profit Point (Strike Price): {strike_price}")
    # Annotate the strike price (max profit point) on the x-axis
    ax1.text(strike_price, max(pdf) * 0.02, f"{strike_price}", fontsize=12, color='purple', ha='center')
    # Annotate the probability of x > strike price
    ax1.text(strike_price + 0.2, max(pdf) * 0.15, 
             f"P(x > Strike Price) = {probability_x_above_strike_price*100:.2f}%", fontsize=12, color="purple")

    # Title and grid
    plt.title("Covered Write Strategy Profit/Loss with Lognormal Distribution of Stock Prices")
    ax1.grid(True)

    # Show the plot
    fig.tight_layout()
    plt.legend(loc='upper left')
    plt.show()
    
    return data

# Example Usage:
stock_price = 3.5  # Current stock price
call_price = 0.5     # Call premium received
strike_price = 3.6 # Strike price of the call option
sigma = 0.5        # Volatility of the stock

# Call the function
results = covered_write_profit_possibility_lognorm(stock_price, call_price, strike_price, sigma)

# If needed, you can access the results like:
#print(results['Break-even Point'])
# print(results['Expected Profit'])
# Out:
# Break-even Point: 3.0000
# Break-even Probability: 62.11%
# Max Profit Point: 3.6000
# Max Profit Probability: 47.75%
# Expected Profit: 0.0141
# Expected Profit Rate: 0.35%

# %%
# Plot Buy Stock Option Profit/Loss
# Stock parameters
stock_price = 3.8

x_min = 3                # Minimum x-axis value
x_max = 5                # Maximum x-axis value

# Generate x range
x = np.linspace(x_min, x_max, 100)
y = buy_stock(x, stock_price)
  
# Calculate break-even point
break_even_x = stock_price
break_even_y = 0
    
# Plotting the graph
plt.plot(x, y, label="Stock profit/loss", color='blue')
plt.xlabel("Stock Price at Expiration")
plt.ylabel("Profit / Loss")
plt.title("Stock profit/loss Chart")
plt.axhline(0, color='black', linewidth=1)  # Adding x-axis line
plt.axvline(0, color='black', linewidth=1)  # Adding y-axis line
plt.grid(True)
plt.legend()
    
# Set x-axis starting at x_min
plt.xlim(left=x_min)
    
# Plot the break-even point
plt.scatter(break_even_x, break_even_y, color="red", zorder=5)  # Red dot for the break-even point
plt.text(break_even_x + 0.1, break_even_y - 0.2, f"Break-even: ({break_even_x}, {break_even_y})", fontsize=12, color="red")

# Show the plot
plt.show()

# %%
# Plot Buy Call Option Profit/Loss

# Option parameters
call_price = 0.375       # Call option price (premium)
strike_price = 4         # Strike price
x_min = 3                # Minimum x-axis value
x_max = 5                # Maximum x-axis value
max_loss = 0 - call_price  # Maximum loss is the call price (since we lose the premium if x < strike_price)

    
# Define the range of x values (stock price at expiration)
x = np.linspace(x_min, x_max, 100)  

    
# Define the corresponding y values using the buy_call function
y = buy_call(x, call_price, strike_price)

# Calculate the break-even point
break_even_x = strike_price + call_price  # The break-even point is the strike price plus the call price
break_even_y = 0

    
# Create the plot
plt.plot(x, y, label="Buy Call Option", color='blue')    

    
# Add labels and title
plt.axhline(0, color='black',linewidth=1)  # x-axis
plt.axvline(0, color='black',linewidth=1)  # y-axis
plt.xlabel("Stock Price at Expiration")
plt.ylabel("Profit / Loss")
plt.title("Buy Call Option Profit/Loss")

    
#Plot the beak-even point
plt.scatter(break_even_x, break_even_y, color="red", zorder=5)  # Red dot for the point
plt.text(break_even_x + 0.03, break_even_y-0.02, f"({break_even_x}, {break_even_y})", fontsize=12, color="red")
    
# Plot max loss point
plt.scatter(x_min, max_loss, color="green", zorder=5)  # Green dot for max loss
plt.text(x_min + 0.03, max_loss + 0.02, f"Max Loss: {max_loss}", fontsize=12, color="green")

    
# Set x-axis starting at x_min
plt.xlim(left=x_min)
    
# Adding grid, legend, and showing the plot
plt.grid(True)
plt.legend()
plt.show()

# %%
# Option parameters
call_price = 0.375       # Call option premium (price received)
strike_price = 4         # Strike price
x_min = 3                # Minimum x-axis value (stock price range)
x_max = 5                # Maximum x-axis value (stock price range)

# Generate stock price range (x)
x = np.linspace(x_min, x_max, 100)

# Calculate corresponding y (profit/loss) for the sell call
y = sell_call(x, call_price, strike_price)

# Plotting the graph
plt.plot(x, y, label="Sell Call Option", color='red')

# Adding labels and title
plt.xlabel("Stock Price at Expiration")
plt.ylabel("Profit / Loss")
plt.title("Sell Call Option Profit/Loss")
plt.axhline(0, color='black',linewidth=1)  # x-axis
plt.axvline(0, color='black',linewidth=1)  # y-axis
plt.grid(True)
plt.legend()

# Break-even point
break_even_x = strike_price + call_price  # Break-even is strike price + call price
break_even_y = 0

# Plot the break-even point
plt.scatter(break_even_x, break_even_y, color="green", zorder=5)  # Green dot for break-even point
plt.text(break_even_x + 0.1, break_even_y - 0.2, f"Break-even: ({break_even_x}, {break_even_y})", fontsize=12, color="green")

# Set x-axis starting at x_min
plt.xlim(left=x_min)

# Show the plot
plt.show()

# %%
# Option parameters
put_price = 0.375        # Put option premium (price paid)
strike_price = 4         # Strike price
x_min = 3                # Minimum x-axis value (stock price range)
x_max = 5                # Maximum x-axis value (stock price range)

# Generate stock price range (x)
x = np.linspace(x_min, x_max, 100)

# Calculate corresponding y (profit/loss) for the buy put
y = buy_put(x, put_price, strike_price)

# Plotting the graph
plt.plot(x, y, label="Buy Put Option", color='purple')

# Adding labels and title
plt.xlabel("Stock Price at Expiration")
plt.ylabel("Profit / Loss")
plt.title("Buy Put Option Profit/Loss")
plt.axhline(0, color='black',linewidth=1)  # x-axis
plt.axvline(0, color='black',linewidth=1)  # y-axis
plt.grid(True)
plt.legend()

# Break-even point
break_even_x = strike_price - put_price  # Break-even is strike price - put price
break_even_y = 0

# Plot the break-even point
plt.scatter(break_even_x, break_even_y, color="green", zorder=5)  # Green dot for break-even point
plt.text(break_even_x + 0.1, break_even_y - 0.2, f"Break-even: ({break_even_x}, {break_even_y})", fontsize=12, color="green")

# Set x-axis starting at x_min
plt.xlim(left=x_min)

# Show the plot
plt.show()

# %%
# Option parameters
put_price = 0.375        # Put option premium (price received)
strike_price = 4         # Strike price
x_min = 3                # Minimum x-axis value (stock price range)
x_max = 5                # Maximum x-axis value (stock price range)

# Generate stock price range (x)
x = np.linspace(x_min, x_max, 100)

# Calculate corresponding y (profit/loss) for the sell put
y = sell_put(x, put_price, strike_price)

# Plotting the graph
plt.plot(x, y, label="Sell Put Option", color='orange')

# Adding labels and title
plt.xlabel("Stock Price at Expiration")
plt.ylabel("Profit / Loss")
plt.title("Sell Put Option Profit/Loss")
plt.axhline(0, color='black',linewidth=1)  # x-axis
plt.axvline(0, color='black',linewidth=1)  # y-axis
plt.grid(True)
plt.legend()

# Break-even point
break_even_x = strike_price - put_price  # Break-even is strike price - put price
break_even_y = 0

# Plot the break-even point
plt.scatter(break_even_x, break_even_y, color="green", zorder=5)  # Green dot for break-even point
plt.text(break_even_x + 0.1, break_even_y - 0.2, f"Break-even: ({break_even_x}, {break_even_y})", fontsize=12, color="green")

# Set x-axis starting at x_min
plt.xlim(left=x_min)

# Show the plot
plt.show()

# %%
# Parameters
stock_price = 3.8         # Stock purchase price
call_price = 0.375      # Call option premium (price received)
strike_price = 4       # Strike price for the call option
x_min = 3               # Minimum x-axis value (stock price range)
x_max = 5               # Maximum x-axis value (stock price range)

# Generate stock price range (x)
x = np.linspace(x_min, x_max, 100)

# Calculate corresponding y (profit/loss) for the covered write strategy
y = covered_write(x, stock_price, call_price, strike_price)

# Plotting the graph
plt.plot(x, y, label="Covered Write Strategy", color='green')

# Adding labels and title
plt.xlabel("Stock Price at Expiration")
plt.ylabel("Profit / Loss")
plt.title("Covered Write Strategy Profit/Loss")
plt.axhline(0, color='black', linewidth=1)  # x-axis
plt.axvline(0, color='black', linewidth=1)  # y-axis
plt.grid(True)
plt.legend()

# Break-even point
break_even_x = stock_price - call_price  # Break-even is buy price - call price
break_even_y = 0

# Plot the break-even point
plt.scatter(break_even_x, break_even_y, color="green", zorder=5)  # Green dot for break-even point
plt.text(break_even_x + 0.1, break_even_y - 0.2, f"Break-even: ({break_even_x}, {break_even_y})", fontsize=12, color="green")

# Set x-axis starting at x_min
plt.xlim(left=x_min)

# Show the plot
plt.show()

# %%
import tkinter as tk
from tkinter import messagebox

# Function to capture the input values and perform the logic
def get_input_values():
    try:
        # Get the input values from the entry widgets
        stock_price = float(stock_price_entry.get())
        call_price = float(call_price_entry.get())
        strike_price = float(strike_price_entry.get())
        sigma = float(sigma_entry.get())              
        
        # Example: print values (you can replace this with your plot or other logic)
        print(f"Buy Price: {stock_price}")
        print(f"Call Price: {call_price}")
        print(f"Strike Price: {strike_price}")
        print(f"Sigma (std dev): {sigma}")
        
        # Show success message
        messagebox.showinfo("Input Received", "Values have been successfully entered!")
        
        # Close the window after submission
        root.destroy()
        
        # Call covered_write_profit_loss funcion and plot the chart
        covered_write_profit_possibility_lognorm(stock_price,call_price,strike_price,sigma)

    except ValueError:
        # If there's a ValueError (non-numeric input), show an error message
        messagebox.showerror("Invalid Input", "Please enter valid numeric values for all fields.")

# Create the main window
root = tk.Tk()
root.title("Option Strategy Inputs")

# Set the window size
root.geometry("400x300")

# Create labels and entry fields for the inputs
tk.Label(root, text="Stock Price:").grid(row=0, column=0, padx=10, pady=10, sticky="w")
stock_price_entry = tk.Entry(root)
stock_price_entry.grid(row=0, column=1, padx=10, pady=10)


tk.Label(root, text="Strike Price:").grid(row=2, column=0, padx=10, pady=10, sticky="w")
strike_price_entry = tk.Entry(root)
strike_price_entry.grid(row=2, column=1, padx=10, pady=10)

tk.Label(root, text="Call Price:").grid(row=1, column=0, padx=10, pady=10, sticky="w")
call_price_entry = tk.Entry(root)
call_price_entry.grid(row=1, column=1, padx=10, pady=10)


tk.Label(root, text="Sigma (Std Dev):").grid(row=4, column=0, padx=10, pady=10, sticky="w")
sigma_entry = tk.Entry(root)
sigma_entry.grid(row=4, column=1, padx=10, pady=10)

# Button to submit the input and perform calculations or plotting
submit_button = tk.Button(root, text="Submit", command=get_input_values)
submit_button.grid(row=5, column=0, columnspan=2, pady=20)

# Run the Tkinter main event loop
root.mainloop()

# %%
# how to calculatge stock mean value and sigma?

# sigma = V * sqrt(T)
# V is the annualized volatility (in decimal form), 20% so V = 0.2
# T is the time horizon in years, typically from the current date to the expiration date of the option or asset.

#mean value = current stock price
#For most practical cases where volatility (sigma) is given, and no drift is assumed, the mean value of the stock price at expiration is just the current stock price.

# %%
# Out:
# Break-even Point: 95.0000
# Break-even Probability: 60.12%
# Max Profit Point: 110.0000
# Max Profit Probability: 31.68%
# Expected Profit: 1.9764
